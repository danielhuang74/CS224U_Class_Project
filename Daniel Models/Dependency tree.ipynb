# %%
'''
Based off of this paper: https://www.cs.utexas.edu/~ml/papers/spk-emnlp-05.pdf

For relation extraction (e.g. '5%' is a 'discount rate'), we build a dependency tree
of the sentence and look at the number with the shortest distance from the target metric to extract
(e.g. 'discount rate')

'''

# %%
import pandas as pd

# %%
exsentence1 = u'Implied present values of cash flows and terminal values were calculated using discount rates ranging from 8% to 9%, reflecting estimates of Advanced Disposal’s weighted average cost of capital.'
exsentence2 = "UBS performed discounted cash flow analyses utilizing financial forecasts and estimates prepared by the management of Advanced Disposal (as more fully described in the section entitled “The Merger (Proposal 1)—Projected Financial Information” beginning on page 52 of this proxy statement). UBS calculated ranges of implied present values (as of January 1, 2019) of the standalone, unlevered, free cash flows that Advanced Disposal was forecasted to generate from January 1, 2019 through December 31, 2023 and of terminal values for Advanced Disposal. Implied terminal values were derived by applying to the projection of Advanced Disposal’s 2023 estimated Market Adjusted EBITDA a range of estimated terminal last twelve months Market Adjusted EBITDA multiples of 9.5x to 11.5x, which range was selected based on current and historical trading Market Adjusted EBITDA multiples of Advanced Disposal and certain of the selected companies. Implied present values of cash flows and terminal values were calculated using discount rates ranging from 8% to 9%, reflecting estimates of Advanced Disposal’s weighted average cost of capital. The discounted cash flow analyses resulted in a range of implied equity values of approximately $25 to $35 per share for Advanced Disposal, as compared to the $33.15 offer price."
exsentence3 = "The discounted cash flow analyses resulted in a range of implied equity values of approximately $25 to $35 per share for Advanced Disposal, as compared to the $33.15 offer price."
exsentence5 = "in performing this analysis, kbw used earnings and asset growth estimates for cadence for 2010 through 2015 from company management and assumed discount rates ranging from 12.0% to 16.0%."

exdocument1 = "discounted cash flow analysis. kbw performed a discounted cash flow analysis to estimate a range of the present values of after-tax cash flows that cadence could provide to equity holders through 2015, assuming a $90.0 million common equity offering in the third quarter of 2010 at $1.00 per share. the analysis assumed a 6.00% underwriting discount and $300,000 of additional offering expenses. in performing this analysis, kbw used earnings and asset growth estimates for cadence for 2010 through 2015 from company management and assumed discount rates ranging from 12.0% to 16.0%. the range of values was determined by adding (1) ;the present value of projected cash dividends to cadence shareholders from 2010 to 2015, assuming excess capital is paid out to cadence shareholders and (2) ;the present value of the terminal value of cadence&#146;s common stock. in calculating the terminal value of cadence, kbw applied multiples ranging from 10.0x to 14.0x 2015 forecasted earnings. in determining cash flows available to shareholders, kbw assumed that cadence would maintain a tangible common equity / tangible assets ratio of 7.00% and any excess capital would be paid out to cadence shareholders. this resulted in a range of values of cadence from $0.93 to $1.32 per share.  kbw also considered and discussed with the cadence board how this analysis would be affected by changes in the underlying assumptions of the capital raise, including variations with respect to the amount raised and offer price per share. to illustrate this impact, kbw performed a similar discounted cash flow analysis assuming capital raises ranging from $80.0 million to $100.0 million at offer prices from $0.50 per share to $1.50 per share. the analysis assumes a 12.0x terminal multiple on 2015 earnings and a 14.0% discount rate. this resulted in a range of values of cadence from $0.57 to $1.64.  kbw stated that the discounted cash flow present value analysis is a widely used valuation methodology but noted that it relies on numerous assumptions, including asset and earnings growth rates, terminal values and discount rates. the analysis did not purport to be indicative of the actual values or expected values of cadence.  "

# %%
INPUT_DOCUMENT = exdocument1
INPUT_SENTENCE = exsentence5
TARGET_METRIC = 'discount rates'

# %%
'''sentence preprocessing: if target metric has a space, remove the space from the sentence
so that it will be treated as one token
'''
#INPUT_DOCUMENT = INPUT_DOCUMENT.replace(TARGET_METRIC, TARGET_METRIC.replace(' ', ''))

#TARGET_METRIC = TARGET_METRIC.replace(' ', '')

# %%
import networkx as nx
import spacy

# %%
def is_number(s):

    
    try:
        float(s)
        return True
    except ValueError:
        return False

# %%
# removes the edge/tree info from the processed num
def unprocess_scores(num_scores):
    temp = []
    
    
    

    for score in num_scores:
        #if(score[0].split('-')[0] == ''):
            #print('numscores = ', num_scores)
            #print('ragga', score[0].split('-')[0], 'ragga')
        if len(score[0].split('-'))<3:
            temp.append((float(score[0].split('-')[0]), score[1]))
        else: # negative number, e.g. '-1-16'
            temp.append((float('-' + score[0].split('-')[1]), score[1]))

    
    return temp

# %%
'''
gets candidate numeric values for the target metric based on the sentence

'''
def get_candidates(sentence):
    sentence = nlp(sentence)
    # Load spacy's dependency tree into a networkx graph
    edges = []

    # get all numbers
    all_nums = []

    target_metric_processed = ''
    #print("Target metric: ", TARGET_METRIC)

    for token in sentence:
        # FYI https://spacy.io/docs/api/token
        for child in token.children:
            edges.append(('{0}-{1}'.format(token.lower_,token.i),
                          '{0}-{1}'.format(child.lower_,child.i)))
            if(is_number(child.lower_)):
                all_nums.append('{0}-{1}'.format(child.lower_,child.i))

            if child.lower_ == str.lower(TARGET_METRIC.replace(' ', '')):
                target_metric_processed = '{0}-{1}'.format(child.lower_,child.i)

    if target_metric_processed == '':
        #print('target metric is empty')
        return [] # will be '' if the target metric is not in the sentence

    graph = nx.Graph(edges)

    # https://networkx.github.io/documentation/networkx-1.10/reference/algorithms.shortest_paths.html

    num_scores = []

    for num in all_nums:
        try:
            shortest_len = nx.shortest_path_length(graph, source=target_metric_processed, target=num)
            #print('Shortest path for {} is {}'.format(num, shortest_len))
            num_scores.append((num, shortest_len))
        except nx.NetworkXNoPath:
            #print('No path between {} and {}'.format(target_metric_processed, num))
            pass

    # unprocess all target_metrics
    #print('this is ns: ', num_scores)
    #print('sentence: ', sentence)
    num_scores = unprocess_scores(num_scores)
    
    return num_scores

# %%
# discard candidates that are obviously not discount rateas
def sanity_check(candidates, sentence):

    #sentence = 'the cash flows and terminal values were then discounted to present value (as of june ;30, 2017) using a selected range of discountrates of 9.5% to 11.5%.'

    #candidates = [(30.0, 7), (2017.0, 8), (9.5, 3), (11.5, 6)]

    # loop over all candidates
    #print('all candidates to loop over: ', candidates)
    
    to_remove = []
    
    for candidate in candidates:
        #candidate = candidates[0]
        #candidate[0]
        #print('curr candidate: ', candidate)

        # check if number followed by a % in original
        window = sentence[sentence.find(str(int(candidate[0]))) : sentence.find(str(int(candidate[0]))) + len(str(candidate[0])) + 3]
        
        if '%' not in window: # is not a percentage
            #print('will remove: ', candidate)
            to_remove.append(candidate)
            
        #else:
            
            #print('window: ', str(window))

        # check if number is too big? TODO
        # before appending to to_remove, check if it's not there
        
    
    # remove candidates
    for candidate in to_remove:
        candidates.remove(candidate)


    return candidates

# %%
def most_probable_metric(all_candidates):
    
    #all_candidates = [[(3.0, 13), (9.25, 6), (10.25, 7)], [(3.0, 13), (4.0, 14), (9.75, 6), (10.75, 7)], [(9.25, 6), (10.25, 7)]]
    if all_candidates == []:
        print('empty allcadnidates in mindst')
        return []
    # find the minimal distance in all sentences
    print('all cands right before mindst: ', all_candidates)
    min_dst = all_candidates[0][0][1]

    for sent_candidates in all_candidates:
        for candidate in sent_candidates:
            if candidate[1] < min_dst:
                min_dst = candidate[1]

    # find all candidates within threshold of the minimum distance (+2)
    probable_candidates = []
    for sent_candidates in all_candidates:
        sent_probable_candidates = []
        for candidate in sent_candidates:
            if candidate[1] <= min_dst+2:
                sent_probable_candidates.append(candidate[0])
        if sent_probable_candidates != []:
            probable_candidates.append(sent_probable_candidates)

    return probable_candidates

# %%
probable_candidates
# Out:
# [[9.25, 10.25], [9.75, 10.75], [9.25, 10.25]]

# %%
import copy

nlp = spacy.load('en')

# https://spacy.io/docs/usage/processing-text
#document = nlp(INPUT_DOCUMENT)

data = pd.read_csv('processedData.csv')

predicted_metrics = []

i = 2

for model in data['Text']:
    
    model = model.replace(TARGET_METRIC, TARGET_METRIC.replace(' ', ''))
    
    
    #print(model)
    document = nlp(model)
    
    all_candidates = [] # for all sentences
    
    for sentence in document.sents:
        sentence = sentence.string.strip()
        
        #print('sentence: ', sentence[:100])
        #print('TARGET_METRIC: ', TARGET_METRIC)
        if TARGET_METRIC.replace(' ', '') in sentence:
            
            candidates = get_candidates(sentence)
            #print('---')
            candidates = sanity_check(candidates, sentence)
            
            print('candidates after SC: ', candidates)
        
            
            if candidates != []:
                all_candidates.append(candidates)
                
    print('all candidates: ', i, all_candidates)
    
    chosen_metrics = most_probable_metric(all_candidates)
    i+=1
        
        
    print('chosen metrics: ', chosen_metrics)
    
    predicted_metrics.append(chosen_metrics)
# Out:
# candidates after SC:  [(12.0, 4), (16.0, 5)]
# candidates after SC:  []
# all candidates:  2 [[(12.0, 4), (16.0, 5)]]
# all cands right before mindst:  [[(12.0, 4), (16.0, 5)]]
# chosen metrics:  [[12.0, 16.0]]
# all candidates:  3 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  4 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  []
# all candidates:  5 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(23.4, 5)]
# candidates after SC:  []
# candidates after SC:  []
# candidates after SC:  [(19.4, 10), (23.4, 11)]
# all candidates:  6 [[(23.4, 5)], [(19.4, 10), (23.4, 11)]]
# all cands right before mindst:  [[(23.4, 5)], [(19.4, 10), (23.4, 11)]]
# chosen metrics:  [[23.4]]
# candidates after SC:  [(11.0, 4), (13.0, 5)]
# all candidates:  7 [[(11.0, 4), (13.0, 5)]]
# all cands right before mindst:  [[(11.0, 4), (13.0, 5)]]
# chosen metrics:  [[11.0, 13.0]]
# candidates after SC:  [(9.0, 4), (11.0, 5)]
# all candidates:  8 [[(9.0, 4), (11.0, 5)]]
# all cands right before mindst:  [[(9.0, 4), (11.0, 5)]]
# chosen metrics:  [[9.0, 11.0]]
# all candidates:  9 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(16.0, 3), (17.0, 4)]
# candidates after SC:  []
# candidates after SC:  []
# candidates after SC:  []
# all candidates:  10 [[(16.0, 3), (17.0, 4)]]
# all cands right before mindst:  [[(16.0, 3), (17.0, 4)]]
# chosen metrics:  [[16.0, 17.0]]
# candidates after SC:  [(9.0, 4), (12.0, 5)]
# candidates after SC:  []
# all candidates:  11 [[(9.0, 4), (12.0, 5)]]
# all cands right before mindst:  [[(9.0, 4), (12.0, 5)]]
# chosen metrics:  [[9.0, 12.0]]
# candidates after SC:  [(5.2, 4), (6.1, 5)]
# all candidates:  12 [[(5.2, 4), (6.1, 5)]]
# all cands right before mindst:  [[(5.2, 4), (6.1, 5)]]
# chosen metrics:  [[5.2, 6.1]]
# all candidates:  13 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  14 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(3.0, 13), (9.25, 6), (10.25, 7)]
# candidates after SC:  [(3.0, 13), (4.0, 14), (9.75, 6), (10.75, 7)]
# candidates after SC:  [(9.25, 6), (10.25, 7)]
# all candidates:  15 [[(3.0, 13), (9.25, 6), (10.25, 7)], [(3.0, 13), (4.0, 14), (9.75, 6), (10.75, 7)], [(9.25, 6), (10.25, 7)]]
# all cands right before mindst:  [[(3.0, 13), (9.25, 6), (10.25, 7)], [(3.0, 13), (4.0, 14), (9.75, 6), (10.75, 7)], [(9.25, 6), (10.25, 7)]]
# chosen metrics:  [[9.25, 10.25], [9.75, 10.75], [9.25, 10.25]]
# candidates after SC:  [(9.5, 3), (11.5, 4)]
# candidates after SC:  []
# all candidates:  16 [[(9.5, 3), (11.5, 4)]]
# all cands right before mindst:  [[(9.5, 3), (11.5, 4)]]
# chosen metrics:  [[9.5, 11.5]]
# candidates after SC:  [(9.0, 4), (11.0, 5)]
# all candidates:  17 [[(9.0, 4), (11.0, 5)]]
# all cands right before mindst:  [[(9.0, 4), (11.0, 5)]]
# chosen metrics:  [[9.0, 11.0]]
# all candidates:  18 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(9.5, 4), (11.5, 5)]
# all candidates:  19 [[(9.5, 4), (11.5, 5)]]
# all cands right before mindst:  [[(9.5, 4), (11.5, 5)]]
# chosen metrics:  [[9.5, 11.5]]
# candidates after SC:  [(10.5, 4), (12.5, 5), (1.0, 3), (2.0, 4)]
# all candidates:  20 [[(10.5, 4), (12.5, 5), (1.0, 3), (2.0, 4)]]
# all cands right before mindst:  [[(10.5, 4), (12.5, 5), (1.0, 3), (2.0, 4)]]
# chosen metrics:  [[10.5, 12.5, 1.0, 2.0]]
# candidates after SC:  [(10.8, 4), (12.8, 5)]
# candidates after SC:  [(9.1, 4), (11.1, 5)]
# all candidates:  21 [[(10.8, 4), (12.8, 5)], [(9.1, 4), (11.1, 5)]]
# all cands right before mindst:  [[(10.8, 4), (12.8, 5)], [(9.1, 4), (11.1, 5)]]
# chosen metrics:  [[10.8, 12.8], [9.1, 11.1]]
# candidates after SC:  []
# all candidates:  22 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(8.0, 4), (10.0, 5)]
# candidates after SC:  [(9.0, 4), (11.0, 5)]
# all candidates:  23 [[(8.0, 4), (10.0, 5)], [(9.0, 4), (11.0, 5)]]
# all cands right before mindst:  [[(8.0, 4), (10.0, 5)], [(9.0, 4), (11.0, 5)]]
# chosen metrics:  [[8.0, 10.0], [9.0, 11.0]]
# candidates after SC:  []
# candidates after SC:  [(12.75, 3), (13.75, 3)]
# candidates after SC:  []
# candidates after SC:  [(10.0, 4), (11.0, 3)]
# all candidates:  24 [[(12.75, 3), (13.75, 3)], [(10.0, 4), (11.0, 3)]]
# all cands right before mindst:  [[(12.75, 3), (13.75, 3)], [(10.0, 4), (11.0, 3)]]
# chosen metrics:  [[12.75, 13.75], [10.0, 11.0]]
# candidates after SC:  [(9.5, 3), (11.5, 6)]
# all candidates:  25 [[(9.5, 3), (11.5, 6)]]
# all cands right before mindst:  [[(9.5, 3), (11.5, 6)]]
# chosen metrics:  [[9.5]]
# candidates after SC:  [(9.0, 10), (11.0, 11), (1.0, 11), (9.0, 4), (11.0, 5), (8.5, 13)]
# all candidates:  26 [[(9.0, 10), (11.0, 11), (1.0, 11), (9.0, 4), (11.0, 5), (8.5, 13)]]
# all cands right before mindst:  [[(9.0, 10), (11.0, 11), (1.0, 11), (9.0, 4), (11.0, 5), (8.5, 13)]]
# chosen metrics:  [[9.0, 11.0]]
# candidates after SC:  []
# candidates after SC:  [(10.0, 4), (12.0, 3)]
# candidates after SC:  []
# candidates after SC:  []
# all candidates:  27 [[(10.0, 4), (12.0, 3)]]
# all cands right before mindst:  [[(10.0, 4), (12.0, 3)]]
# chosen metrics:  [[10.0, 12.0]]
# candidates after SC:  [(17.8, 4), (20.8, 5), (25.0, 9), (75.0, 9), (2.0, 9), (4.0, 10)]
# all candidates:  28 [[(17.8, 4), (20.8, 5), (25.0, 9), (75.0, 9), (2.0, 9), (4.0, 10)]]
# all cands right before mindst:  [[(17.8, 4), (20.8, 5), (25.0, 9), (75.0, 9), (2.0, 9), (4.0, 10)]]
# chosen metrics:  [[17.8, 20.8]]
# candidates after SC:  [(18.3, 4), (20.3, 5), (2.0, 5), (4.0, 4)]
# all candidates:  29 [[(18.3, 4), (20.3, 5), (2.0, 5), (4.0, 4)]]
# all cands right before mindst:  [[(18.3, 4), (20.3, 5), (2.0, 5), (4.0, 4)]]
# chosen metrics:  [[18.3, 20.3, 2.0, 4.0]]
# candidates after SC:  [(17.0, 8), (25.0, 7), (23.3, 5), (19.0, 9), (30.0, 8)]
# candidates after SC:  [(17.0, 8), (25.0, 7), (23.7, 5), (19.0, 9), (30.0, 8)]
# candidates after SC:  []
# candidates after SC:  []
# candidates after SC:  []
# candidates after SC:  []
# all candidates:  30 [[(17.0, 8), (25.0, 7), (23.3, 5), (19.0, 9), (30.0, 8)], [(17.0, 8), (25.0, 7), (23.7, 5), (19.0, 9), (30.0, 8)]]
# all cands right before mindst:  [[(17.0, 8), (25.0, 7), (23.3, 5), (19.0, 9), (30.0, 8)], [(17.0, 8), (25.0, 7), (23.7, 5), (19.0, 9), (30.0, 8)]]
# chosen metrics:  [[25.0, 23.3], [25.0, 23.7]]
# all candidates:  31 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(10.0, 4), (12.0, 5)]
# all candidates:  32 [[(10.0, 4), (12.0, 5)]]
# all cands right before mindst:  [[(10.0, 4), (12.0, 5)]]
# chosen metrics:  [[10.0, 12.0]]
# candidates after SC:  []
# candidates after SC:  []
# all candidates:  33 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  []
# all candidates:  34 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(19.0, 4), (21.0, 4)]
# all candidates:  35 [[(19.0, 4), (21.0, 4)]]
# all cands right before mindst:  [[(19.0, 4), (21.0, 4)]]
# chosen metrics:  [[19.0, 21.0]]
# candidates after SC:  [(7.0, 4), (8.0, 5)]
# all candidates:  36 [[(7.0, 4), (8.0, 5)]]
# all cands right before mindst:  [[(7.0, 4), (8.0, 5)]]
# chosen metrics:  [[7.0, 8.0]]
# candidates after SC:  [(7.3, 3), (9.3, 3)]
# candidates after SC:  []
# candidates after SC:  [(7.3, 10), (7.7, 5)]
# all candidates:  37 [[(7.3, 3), (9.3, 3)], [(7.3, 10), (7.7, 5)]]
# all cands right before mindst:  [[(7.3, 3), (9.3, 3)], [(7.3, 10), (7.7, 5)]]
# chosen metrics:  [[7.3, 9.3], [7.7]]
# candidates after SC:  [(10.2, 4)]
# candidates after SC:  [(5.0, 7), (16.8, 4)]
# candidates after SC:  [(50.0, 15), (100.0, 15), (7.5, 15), (12.2, 16), (50.0, 12), (100.0, 12), (7.5, 12), (18.8, 9)]
# all candidates:  38 [[(10.2, 4)], [(5.0, 7), (16.8, 4)], [(50.0, 15), (100.0, 15), (7.5, 15), (12.2, 16), (50.0, 12), (100.0, 12), (7.5, 12), (18.8, 9)]]
# all cands right before mindst:  [[(10.2, 4)], [(5.0, 7), (16.8, 4)], [(50.0, 15), (100.0, 15), (7.5, 15), (12.2, 16), (50.0, 12), (100.0, 12), (7.5, 12), (18.8, 9)]]
# chosen metrics:  [[10.2], [16.8]]
# candidates after SC:  [(13.5, 3), (3.0, 11), (5.0, 8)]
# candidates after SC:  []
# all candidates:  39 [[(13.5, 3), (3.0, 11), (5.0, 8)]]
# all cands right before mindst:  [[(13.5, 3), (3.0, 11), (5.0, 8)]]
# chosen metrics:  [[13.5]]
# candidates after SC:  [(12.0, 4), (14.0, 5)]
# all candidates:  40 [[(12.0, 4), (14.0, 5)]]
# all cands right before mindst:  [[(12.0, 4), (14.0, 5)]]
# chosen metrics:  [[12.0, 14.0]]
# candidates after SC:  [(8.0, 16), (10.0, 16), (5.0, 12)]
# all candidates:  41 [[(8.0, 16), (10.0, 16), (5.0, 12)]]
# all cands right before mindst:  [[(8.0, 16), (10.0, 16), (5.0, 12)]]
# chosen metrics:  [[5.0]]
# candidates after SC:  [(8.5, 4), (10.5, 5)]
# all candidates:  42 [[(8.5, 4), (10.5, 5)]]
# all cands right before mindst:  [[(8.5, 4), (10.5, 5)]]
# chosen metrics:  [[8.5, 10.5]]
# candidates after SC:  [(8.0, 2), (7.0, 3)]
# all candidates:  43 [[(8.0, 2), (7.0, 3)]]
# all cands right before mindst:  [[(8.0, 2), (7.0, 3)]]
# chosen metrics:  [[8.0, 7.0]]
# all candidates:  44 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(7.0, 6), (8.0, 7)]
# all candidates:  45 [[(7.0, 6), (8.0, 7)]]
# all cands right before mindst:  [[(7.0, 6), (8.0, 7)]]
# chosen metrics:  [[7.0, 8.0]]
# candidates after SC:  [(10.5, 4), (11.5, 6), (5.5, 20)]
# candidates after SC:  [(11.0, 4), (12.0, 5), (5.5, 16)]
# all candidates:  46 [[(10.5, 4), (11.5, 6), (5.5, 20)], [(11.0, 4), (12.0, 5), (5.5, 16)]]
# all cands right before mindst:  [[(10.5, 4), (11.5, 6), (5.5, 20)], [(11.0, 4), (12.0, 5), (5.5, 16)]]
# chosen metrics:  [[10.5, 11.5], [11.0, 12.0]]
# candidates after SC:  [(7.0, 4)]
# all candidates:  47 [[(7.0, 4)]]
# all cands right before mindst:  [[(7.0, 4)]]
# chosen metrics:  [[7.0]]
# candidates after SC:  [(8.5, 4), (10.0, 5)]
# all candidates:  48 [[(8.5, 4), (10.0, 5)]]
# all cands right before mindst:  [[(8.5, 4), (10.0, 5)]]
# chosen metrics:  [[8.5, 10.0]]
# candidates after SC:  [(10.0, 5)]
# candidates after SC:  []
# all candidates:  49 [[(10.0, 5)]]
# all cands right before mindst:  [[(10.0, 5)]]
# chosen metrics:  [[10.0]]
# candidates after SC:  [(9.5, 3), (11.5, 4)]
# candidates after SC:  [(9.5, 3), (11.5, 4)]
# candidates after SC:  [(9.5, 3), (11.5, 4)]
# candidates after SC:  [(9.5, 3), (11.5, 4)]
# all candidates:  50 [[(9.5, 3), (11.5, 4)], [(9.5, 3), (11.5, 4)], [(9.5, 3), (11.5, 4)], [(9.5, 3), (11.5, 4)]]
# all cands right before mindst:  [[(9.5, 3), (11.5, 4)], [(9.5, 3), (11.5, 4)], [(9.5, 3), (11.5, 4)], [(9.5, 3), (11.5, 4)]]
# chosen metrics:  [[9.5, 11.5], [9.5, 11.5], [9.5, 11.5], [9.5, 11.5]]
# candidates after SC:  [(9.5, 3), (10.5, 4)]
# all candidates:  51 [[(9.5, 3), (10.5, 4)]]
# all cands right before mindst:  [[(9.5, 3), (10.5, 4)]]
# chosen metrics:  [[9.5, 10.5]]
# candidates after SC:  [(11.5, 3), (12.5, 4)]
# all candidates:  52 [[(11.5, 3), (12.5, 4)]]
# all cands right before mindst:  [[(11.5, 3), (12.5, 4)]]
# chosen metrics:  [[11.5, 12.5]]
# candidates after SC:  [(12.0, 3), (16.0, 4), (10.5, 12), (13.5, 10)]
# candidates after SC:  []
# all candidates:  53 [[(12.0, 3), (16.0, 4), (10.5, 12), (13.5, 10)]]
# all cands right before mindst:  [[(12.0, 3), (16.0, 4), (10.5, 12), (13.5, 10)]]
# chosen metrics:  [[12.0, 16.0]]
# all candidates:  54 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  []
# candidates after SC:  [(10.75, 3), (11.75, 3)]
# candidates after SC:  []
# candidates after SC:  [(10.75, 3), (11.75, 3)]
# all candidates:  55 [[(10.75, 3), (11.75, 3)], [(10.75, 3), (11.75, 3)]]
# all cands right before mindst:  [[(10.75, 3), (11.75, 3)], [(10.75, 3), (11.75, 3)]]
# chosen metrics:  [[10.75, 11.75], [10.75, 11.75]]
# all candidates:  56 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  57 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  58 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(11.95, 6), (19.0, 4), (25.0, 5)]
# candidates after SC:  []
# all candidates:  59 [[(11.95, 6), (19.0, 4), (25.0, 5)]]
# all cands right before mindst:  [[(11.95, 6), (19.0, 4), (25.0, 5)]]
# chosen metrics:  [[11.95, 19.0, 25.0]]
# candidates after SC:  [(8.5, 4), (10.5, 5)]
# candidates after SC:  [(8.5, 4), (10.5, 5)]
# all candidates:  60 [[(8.5, 4), (10.5, 5)], [(8.5, 4), (10.5, 5)]]
# all cands right before mindst:  [[(8.5, 4), (10.5, 5)], [(8.5, 4), (10.5, 5)]]
# chosen metrics:  [[8.5, 10.5], [8.5, 10.5]]
# candidates after SC:  [(9.0, 4), (11.0, 5)]
# candidates after SC:  [(8.0, 4), (10.0, 5), (1.0, 3)]
# candidates after SC:  [(8.0, 4), (10.0, 5), (4.0, 15)]
# all candidates:  61 [[(9.0, 4), (11.0, 5)], [(8.0, 4), (10.0, 5), (1.0, 3)], [(8.0, 4), (10.0, 5), (4.0, 15)]]
# all cands right before mindst:  [[(9.0, 4), (11.0, 5)], [(8.0, 4), (10.0, 5), (1.0, 3)], [(8.0, 4), (10.0, 5), (4.0, 15)]]
# chosen metrics:  [[9.0, 11.0], [8.0, 10.0, 1.0], [8.0, 10.0]]
# candidates after SC:  [(15.0, 5), (20.0, 4)]
# all candidates:  62 [[(15.0, 5), (20.0, 4)]]
# all cands right before mindst:  [[(15.0, 5), (20.0, 4)]]
# chosen metrics:  [[15.0, 20.0]]
# candidates after SC:  [(13.8, 4)]
# all candidates:  63 [[(13.8, 4)]]
# all cands right before mindst:  [[(13.8, 4)]]
# chosen metrics:  [[13.8]]
# all candidates:  64 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  65 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  66 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(11.0, 4)]
# candidates after SC:  [(4.2, 9), (6.9, 10)]
# candidates after SC:  [(11.0, 4), (13.0, 5)]
# candidates after SC:  [(11.0, 4), (13.0, 3)]
# all candidates:  67 [[(11.0, 4)], [(4.2, 9), (6.9, 10)], [(11.0, 4), (13.0, 5)], [(11.0, 4), (13.0, 3)]]
# all cands right before mindst:  [[(11.0, 4)], [(4.2, 9), (6.9, 10)], [(11.0, 4), (13.0, 5)], [(11.0, 4), (13.0, 3)]]
# chosen metrics:  [[11.0], [11.0, 13.0], [11.0, 13.0]]
# candidates after SC:  [(8.5, 4), (9.0, 5)]
# candidates after SC:  [(8.5, 4), (9.0, 5)]
# candidates after SC:  [(8.5, 10), (9.0, 11)]
# all candidates:  68 [[(8.5, 4), (9.0, 5)], [(8.5, 4), (9.0, 5)], [(8.5, 10), (9.0, 11)]]
# all cands right before mindst:  [[(8.5, 4), (9.0, 5)], [(8.5, 4), (9.0, 5)], [(8.5, 10), (9.0, 11)]]
# chosen metrics:  [[8.5, 9.0], [8.5, 9.0]]
# candidates after SC:  [(16.0, 5)]
# all candidates:  69 [[(16.0, 5)]]
# all cands right before mindst:  [[(16.0, 5)]]
# chosen metrics:  [[16.0]]
# candidates after SC:  [(12.25, 4), (14.25, 5)]
# all candidates:  70 [[(12.25, 4), (14.25, 5)]]
# all cands right before mindst:  [[(12.25, 4), (14.25, 5)]]
# chosen metrics:  [[12.25, 14.25]]
# candidates after SC:  []
# candidates after SC:  []
# candidates after SC:  []
# candidates after SC:  []
# candidates after SC:  []
# all candidates:  71 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  72 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(9.5, 4)]
# all candidates:  73 [[(9.5, 4)]]
# all cands right before mindst:  [[(9.5, 4)]]
# chosen metrics:  [[9.5]]
# candidates after SC:  [(9.0, 4), (10.0, 5)]
# candidates after SC:  []
# all candidates:  74 [[(9.0, 4), (10.0, 5)]]
# all cands right before mindst:  [[(9.0, 4), (10.0, 5)]]
# chosen metrics:  [[9.0, 10.0]]
# candidates after SC:  []
# candidates after SC:  [(10.0, 2), (8.0, 3), (1.286, 4)]
# all candidates:  75 [[(10.0, 2), (8.0, 3), (1.286, 4)]]
# all cands right before mindst:  [[(10.0, 2), (8.0, 3), (1.286, 4)]]
# chosen metrics:  [[10.0, 8.0, 1.286]]
# all candidates:  76 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(10.0, 7), (11.0, 8), (15.5, 5)]
# candidates after SC:  []
# all candidates:  77 [[(10.0, 7), (11.0, 8), (15.5, 5)]]
# all cands right before mindst:  [[(10.0, 7), (11.0, 8), (15.5, 5)]]
# chosen metrics:  [[10.0, 15.5]]
# all candidates:  78 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(13.0, 4), (15.0, 5)]
# candidates after SC:  [(13.0, 4), (15.0, 5)]
# all candidates:  79 [[(13.0, 4), (15.0, 5)], [(13.0, 4), (15.0, 5)]]
# all cands right before mindst:  [[(13.0, 4), (15.0, 5)], [(13.0, 4), (15.0, 5)]]
# chosen metrics:  [[13.0, 15.0], [13.0, 15.0]]
# all candidates:  80 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(3.0, 11), (12.0, 9), (16.0, 10)]
# candidates after SC:  []
# all candidates:  81 [[(3.0, 11), (12.0, 9), (16.0, 10)]]
# all cands right before mindst:  [[(3.0, 11), (12.0, 9), (16.0, 10)]]
# chosen metrics:  [[3.0, 12.0, 16.0]]
# candidates after SC:  [(-1.0, 10), (1.0, 10), (1.0, 3), (25.0, 7), (35.0, 6)]
# candidates after SC:  [(13.0, 4), (17.0, 3), (1.0, 11), (-1.0, 10), (1.0, 11)]
# all candidates:  82 [[(-1.0, 10), (1.0, 10), (1.0, 3), (25.0, 7), (35.0, 6)], [(13.0, 4), (17.0, 3), (1.0, 11), (-1.0, 10), (1.0, 11)]]
# all cands right before mindst:  [[(-1.0, 10), (1.0, 10), (1.0, 3), (25.0, 7), (35.0, 6)], [(13.0, 4), (17.0, 3), (1.0, 11), (-1.0, 10), (1.0, 11)]]
# chosen metrics:  [[1.0], [13.0, 17.0]]
# candidates after SC:  [(17.5, 5), (17.4, 5), (1.0, 6), (15.0, 4), (23.0, 5)]
# candidates after SC:  [(15.5, 8), (18.4, 19)]
# candidates after SC:  [(15.0, 4), (23.0, 5)]
# candidates after SC:  []
# all candidates:  83 [[(17.5, 5), (17.4, 5), (1.0, 6), (15.0, 4), (23.0, 5)], [(15.5, 8), (18.4, 19)], [(15.0, 4), (23.0, 5)]]
# all cands right before mindst:  [[(17.5, 5), (17.4, 5), (1.0, 6), (15.0, 4), (23.0, 5)], [(15.5, 8), (18.4, 19)], [(15.0, 4), (23.0, 5)]]
# chosen metrics:  [[17.5, 17.4, 1.0, 15.0, 23.0], [15.0, 23.0]]
# candidates after SC:  [(12.0, 3)]
# all candidates:  84 [[(12.0, 3)]]
# all cands right before mindst:  [[(12.0, 3)]]
# chosen metrics:  [[12.0]]
# candidates after SC:  [(16.0, 6), (16.0, 3)]
# all candidates:  85 [[(16.0, 6), (16.0, 3)]]
# all cands right before mindst:  [[(16.0, 6), (16.0, 3)]]
# chosen metrics:  [[16.0]]
# candidates after SC:  [(9.5, 3), (13.5, 4)]
# candidates after SC:  []
# all candidates:  86 [[(9.5, 3), (13.5, 4)]]
# all cands right before mindst:  [[(9.5, 3), (13.5, 4)]]
# chosen metrics:  [[9.5, 13.5]]
# candidates after SC:  []
# candidates after SC:  []
# all candidates:  87 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(9.0, 4)]
# all candidates:  88 [[(9.0, 4)]]
# all cands right before mindst:  [[(9.0, 4)]]
# chosen metrics:  [[9.0]]
# candidates after SC:  [(7.5, 4), (9.0, 5)]
# candidates after SC:  [(9.0, 7)]
# candidates after SC:  [(7.5, 4), (9.0, 5)]
# all candidates:  89 [[(7.5, 4), (9.0, 5)], [(9.0, 7)], [(7.5, 4), (9.0, 5)]]
# all cands right before mindst:  [[(7.5, 4), (9.0, 5)], [(9.0, 7)], [(7.5, 4), (9.0, 5)]]
# chosen metrics:  [[7.5, 9.0], [7.5, 9.0]]
# candidates after SC:  []
# all candidates:  90 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(9.5, 3), (11.5, 4)]
# all candidates:  91 [[(9.5, 3), (11.5, 4)]]
# all cands right before mindst:  [[(9.5, 3), (11.5, 4)]]
# chosen metrics:  [[9.5, 11.5]]
# all candidates:  92 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  93 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  []
# all candidates:  94 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  95 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  96 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  97 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  98 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  99 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  100 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(18.0, 4), (24.0, 5)]
# all candidates:  101 [[(18.0, 4), (24.0, 5)]]
# all cands right before mindst:  [[(18.0, 4), (24.0, 5)]]
# chosen metrics:  [[18.0, 24.0]]
# candidates after SC:  [(32.0, 6), (24.0, 5), (29.0, 4)]
# all candidates:  102 [[(32.0, 6), (24.0, 5), (29.0, 4)]]
# all cands right before mindst:  [[(32.0, 6), (24.0, 5), (29.0, 4)]]
# chosen metrics:  [[32.0, 24.0, 29.0]]
# candidates after SC:  [(12.0, 3), (15.0, 3), (8.0, 11)]
# candidates after SC:  [(10.0, 5), (13.0, 3), (4.0, 8), (5.0, 12), (3.0, 13), (8.0, 10)]
# candidates after SC:  []
# all candidates:  103 [[(12.0, 3), (15.0, 3), (8.0, 11)], [(10.0, 5), (13.0, 3), (4.0, 8), (5.0, 12), (3.0, 13), (8.0, 10)]]
# all cands right before mindst:  [[(12.0, 3), (15.0, 3), (8.0, 11)], [(10.0, 5), (13.0, 3), (4.0, 8), (5.0, 12), (3.0, 13), (8.0, 10)]]
# chosen metrics:  [[12.0, 15.0], [10.0, 13.0]]
# all candidates:  104 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(10.0, 3), (12.5, 4), (15.0, 5), (30.0, 8)]
# all candidates:  105 [[(10.0, 3), (12.5, 4), (15.0, 5), (30.0, 8)]]
# all cands right before mindst:  [[(10.0, 3), (12.5, 4), (15.0, 5), (30.0, 8)]]
# chosen metrics:  [[10.0, 12.5, 15.0]]
# candidates after SC:  []
# candidates after SC:  [(6.2, 10)]
# all candidates:  106 [[(6.2, 10)]]
# all cands right before mindst:  [[(6.2, 10)]]
# chosen metrics:  [[6.2]]
# candidates after SC:  [(23.0, 5)]
# candidates after SC:  [(20.0, 4), (23.0, 5)]
# all candidates:  107 [[(23.0, 5)], [(20.0, 4), (23.0, 5)]]
# all cands right before mindst:  [[(23.0, 5)], [(20.0, 4), (23.0, 5)]]
# chosen metrics:  [[23.0], [20.0, 23.0]]
# candidates after SC:  [(8.0, 3), (9.0, 4)]
# candidates after SC:  [(8.5, 3), (9.5, 4)]
# all candidates:  108 [[(8.0, 3), (9.0, 4)], [(8.5, 3), (9.5, 4)]]
# all cands right before mindst:  [[(8.0, 3), (9.0, 4)], [(8.5, 3), (9.5, 4)]]
# chosen metrics:  [[8.0, 9.0], [8.5, 9.5]]
# candidates after SC:  [(15.0, 3), (20.0, 4)]
# all candidates:  109 [[(15.0, 3), (20.0, 4)]]
# all cands right before mindst:  [[(15.0, 3), (20.0, 4)]]
# chosen metrics:  [[15.0, 20.0]]
# candidates after SC:  [(21.0, 5)]
# all candidates:  110 [[(21.0, 5)]]
# all cands right before mindst:  [[(21.0, 5)]]
# chosen metrics:  [[21.0]]
# candidates after SC:  [(10.4, 4), (14.4, 5)]
# all candidates:  111 [[(10.4, 4), (14.4, 5)]]
# all cands right before mindst:  [[(10.4, 4), (14.4, 5)]]
# chosen metrics:  [[10.4, 14.4]]
# candidates after SC:  [(11.5, 4), (13.5, 5)]
# all candidates:  112 [[(11.5, 4), (13.5, 5)]]
# all cands right before mindst:  [[(11.5, 4), (13.5, 5)]]
# chosen metrics:  [[11.5, 13.5]]
# candidates after SC:  [(8.6, 5), (10.0, 3)]
# candidates after SC:  [(8.0, 5), (9.4, 3)]
# all candidates:  113 [[(8.6, 5), (10.0, 3)], [(8.0, 5), (9.4, 3)]]
# all cands right before mindst:  [[(8.6, 5), (10.0, 3)], [(8.0, 5), (9.4, 3)]]
# chosen metrics:  [[8.6, 10.0], [8.0, 9.4]]
# candidates after SC:  []
# candidates after SC:  []
# all candidates:  114 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(7.5, 6), (9.5, 7)]
# all candidates:  115 [[(7.5, 6), (9.5, 7)]]
# all cands right before mindst:  [[(7.5, 6), (9.5, 7)]]
# chosen metrics:  [[7.5, 9.5]]
# candidates after SC:  [(10.5, 3)]
# candidates after SC:  [(2.5, 12), (3.5, 9)]
# all candidates:  116 [[(10.5, 3)], [(2.5, 12), (3.5, 9)]]
# all cands right before mindst:  [[(10.5, 3)], [(2.5, 12), (3.5, 9)]]
# chosen metrics:  [[10.5]]
# candidates after SC:  [(11.0, 4), (13.0, 3)]
# candidates after SC:  []
# candidates after SC:  []
# all candidates:  117 [[(11.0, 4), (13.0, 3)]]
# all cands right before mindst:  [[(11.0, 4), (13.0, 3)]]
# chosen metrics:  [[11.0, 13.0]]
# candidates after SC:  [(9.0, 4), (12.0, 5)]
# candidates after SC:  []
# all candidates:  118 [[(9.0, 4), (12.0, 5)]]
# all cands right before mindst:  [[(9.0, 4), (12.0, 5)]]
# chosen metrics:  [[9.0, 12.0]]
# candidates after SC:  [(18.0, 3), (22.0, 5)]
# all candidates:  119 [[(18.0, 3), (22.0, 5)]]
# all cands right before mindst:  [[(18.0, 3), (22.0, 5)]]
# chosen metrics:  [[18.0, 22.0]]
# candidates after SC:  [(7.9, 4), (8.9, 5)]
# candidates after SC:  []
# candidates after SC:  [(7.0, 4), (8.0, 5)]
# candidates after SC:  []
# all candidates:  120 [[(7.9, 4), (8.9, 5)], [(7.0, 4), (8.0, 5)]]
# all cands right before mindst:  [[(7.9, 4), (8.9, 5)], [(7.0, 4), (8.0, 5)]]
# chosen metrics:  [[7.9, 8.9], [7.0, 8.0]]
# candidates after SC:  [(7.5, 4), (8.5, 5)]
# all candidates:  121 [[(7.5, 4), (8.5, 5)]]
# all cands right before mindst:  [[(7.5, 4), (8.5, 5)]]
# chosen metrics:  [[7.5, 8.5]]
# candidates after SC:  [(7.0, 5), (9.0, 4)]
# candidates after SC:  [(7.0, 6), (9.0, 4)]
# candidates after SC:  []
# all candidates:  122 [[(7.0, 5), (9.0, 4)], [(7.0, 6), (9.0, 4)]]
# all cands right before mindst:  [[(7.0, 5), (9.0, 4)], [(7.0, 6), (9.0, 4)]]
# chosen metrics:  [[7.0, 9.0], [7.0, 9.0]]
# all candidates:  123 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  124 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(7.25, 6), (7.75, 7)]
# candidates after SC:  [(7.25, 6), (7.75, 7)]
# all candidates:  125 [[(7.25, 6), (7.75, 7)], [(7.25, 6), (7.75, 7)]]
# all cands right before mindst:  [[(7.25, 6), (7.75, 7)], [(7.25, 6), (7.75, 7)]]
# chosen metrics:  [[7.25, 7.75], [7.25, 7.75]]
# all candidates:  126 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(8.5, 4), (10.5, 5)]
# candidates after SC:  [(8.5, 4)]
# candidates after SC:  [(6.4, 4), (8.4, 5)]
# candidates after SC:  [(6.4, 4), (8.4, 5)]
# candidates after SC:  [(7.5, 10), (9.5, 11)]
# candidates after SC:  [(7.5, 4)]
# all candidates:  127 [[(8.5, 4), (10.5, 5)], [(8.5, 4)], [(6.4, 4), (8.4, 5)], [(6.4, 4), (8.4, 5)], [(7.5, 10), (9.5, 11)], [(7.5, 4)]]
# all cands right before mindst:  [[(8.5, 4), (10.5, 5)], [(8.5, 4)], [(6.4, 4), (8.4, 5)], [(6.4, 4), (8.4, 5)], [(7.5, 10), (9.5, 11)], [(7.5, 4)]]
# chosen metrics:  [[8.5, 10.5], [8.5], [6.4, 8.4], [6.4, 8.4], [7.5]]
# candidates after SC:  [(9.0, 4), (13.0, 5)]
# candidates after SC:  [(9.0, 4), (13.0, 5)]
# all candidates:  128 [[(9.0, 4), (13.0, 5)], [(9.0, 4), (13.0, 5)]]
# all cands right before mindst:  [[(9.0, 4), (13.0, 5)], [(9.0, 4), (13.0, 5)]]
# chosen metrics:  [[9.0, 13.0], [9.0, 13.0]]
# candidates after SC:  [(7.5, 4), (8.5, 5)]
# all candidates:  129 [[(7.5, 4), (8.5, 5)]]
# all cands right before mindst:  [[(7.5, 4), (8.5, 5)]]
# chosen metrics:  [[7.5, 8.5]]
# all candidates:  130 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(11.0, 3), (15.0, 5)]
# all candidates:  131 [[(11.0, 3), (15.0, 5)]]
# all cands right before mindst:  [[(11.0, 3), (15.0, 5)]]
# chosen metrics:  [[11.0, 15.0]]
# all candidates:  132 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  133 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(11.5, 5)]
# all candidates:  134 [[(11.5, 5)]]
# all cands right before mindst:  [[(11.5, 5)]]
# chosen metrics:  [[11.5]]
# candidates after SC:  [(24.1, 10), (26.1, 11), (14.4, 3), (16.4, 4)]
# all candidates:  135 [[(24.1, 10), (26.1, 11), (14.4, 3), (16.4, 4)]]
# all cands right before mindst:  [[(24.1, 10), (26.1, 11), (14.4, 3), (16.4, 4)]]
# chosen metrics:  [[14.4, 16.4]]
# candidates after SC:  [(11.0, 18), (18.0, 15)]
# all candidates:  136 [[(11.0, 18), (18.0, 15)]]
# all cands right before mindst:  [[(11.0, 18), (18.0, 15)]]
# chosen metrics:  [[18.0]]
# candidates after SC:  [(10.3, 4), (12.3, 5)]
# all candidates:  137 [[(10.3, 4), (12.3, 5)]]
# all cands right before mindst:  [[(10.3, 4), (12.3, 5)]]
# chosen metrics:  [[10.3, 12.3]]
# all candidates:  138 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(50.0, 10), (25.0, 11), (9.0, 4)]
# candidates after SC:  [(50.0, 11), (25.0, 10)]
# candidates after SC:  [(9.0, 4), (14.0, 5)]
# all candidates:  139 [[(50.0, 10), (25.0, 11), (9.0, 4)], [(50.0, 11), (25.0, 10)], [(9.0, 4), (14.0, 5)]]
# all cands right before mindst:  [[(50.0, 10), (25.0, 11), (9.0, 4)], [(50.0, 11), (25.0, 10)], [(9.0, 4), (14.0, 5)]]
# chosen metrics:  [[9.0], [9.0, 14.0]]
# candidates after SC:  [(10.0, 4), (12.3, 5)]
# all candidates:  140 [[(10.0, 4), (12.3, 5)]]
# all cands right before mindst:  [[(10.0, 4), (12.3, 5)]]
# chosen metrics:  [[10.0, 12.3]]
# all candidates:  141 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(10.0, 4), (11.0, 5)]
# candidates after SC:  [(8.0, 4), (9.0, 5)]
# all candidates:  142 [[(10.0, 4), (11.0, 5)], [(8.0, 4), (9.0, 5)]]
# all cands right before mindst:  [[(10.0, 4), (11.0, 5)], [(8.0, 4), (9.0, 5)]]
# chosen metrics:  [[10.0, 11.0], [8.0, 9.0]]
# all candidates:  143 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  []
# candidates after SC:  []
# all candidates:  144 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(9.0, 4), (10.1, 5)]
# all candidates:  145 [[(9.0, 4), (10.1, 5)]]
# all cands right before mindst:  [[(9.0, 4), (10.1, 5)]]
# chosen metrics:  [[9.0, 10.1]]
# candidates after SC:  [(8.5, 3), (9.5, 4)]
# all candidates:  146 [[(8.5, 3), (9.5, 4)]]
# all cands right before mindst:  [[(8.5, 3), (9.5, 4)]]
# chosen metrics:  [[8.5, 9.5]]
# all candidates:  147 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(8.0, 4), (10.0, 5)]
# candidates after SC:  [(8.0, 4), (10.0, 5)]
# all candidates:  148 [[(8.0, 4), (10.0, 5)], [(8.0, 4), (10.0, 5)]]
# all cands right before mindst:  [[(8.0, 4), (10.0, 5)], [(8.0, 4), (10.0, 5)]]
# chosen metrics:  [[8.0, 10.0], [8.0, 10.0]]
# candidates after SC:  [(7.9, 4), (8.9, 5)]
# candidates after SC:  []
# candidates after SC:  [(7.0, 4), (8.0, 5)]
# candidates after SC:  []
# all candidates:  149 [[(7.9, 4), (8.9, 5)], [(7.0, 4), (8.0, 5)]]
# all cands right before mindst:  [[(7.9, 4), (8.9, 5)], [(7.0, 4), (8.0, 5)]]
# chosen metrics:  [[7.9, 8.9], [7.0, 8.0]]
# candidates after SC:  [(8.75, 4)]
# all candidates:  150 [[(8.75, 4)]]
# all cands right before mindst:  [[(8.75, 4)]]
# chosen metrics:  [[8.75]]
# all candidates:  151 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  []
# candidates after SC:  []
# all candidates:  152 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  153 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(7.0, 4), (8.0, 3)]
# all candidates:  154 [[(7.0, 4), (8.0, 3)]]
# all cands right before mindst:  [[(7.0, 4), (8.0, 3)]]
# chosen metrics:  [[7.0, 8.0]]
# candidates after SC:  [(8.9, 4), (10.9, 5)]
# all candidates:  155 [[(8.9, 4), (10.9, 5)]]
# all cands right before mindst:  [[(8.9, 4), (10.9, 5)]]
# chosen metrics:  [[8.9, 10.9]]
# all candidates:  156 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(11.8, 4), (13.8, 5), (12.8, 17)]
# all candidates:  157 [[(11.8, 4), (13.8, 5), (12.8, 17)]]
# all cands right before mindst:  [[(11.8, 4), (13.8, 5), (12.8, 17)]]
# chosen metrics:  [[11.8, 13.8]]
# all candidates:  158 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  159 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  160 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(11.0, 4), (15.0, 5)]
# candidates after SC:  []
# all candidates:  161 [[(11.0, 4), (15.0, 5)]]
# all cands right before mindst:  [[(11.0, 4), (15.0, 5)]]
# chosen metrics:  [[11.0, 15.0]]
# all candidates:  162 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(8.0, 4), (10.0, 5)]
# all candidates:  163 [[(8.0, 4), (10.0, 5)]]
# all cands right before mindst:  [[(8.0, 4), (10.0, 5)]]
# chosen metrics:  [[8.0, 10.0]]
# candidates after SC:  []
# all candidates:  164 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(5.75, 4), (6.75, 5)]
# candidates after SC:  [(5.5, 4), (6.5, 5)]
# all candidates:  165 [[(5.75, 4), (6.75, 5)], [(5.5, 4), (6.5, 5)]]
# all cands right before mindst:  [[(5.75, 4), (6.75, 5)], [(5.5, 4), (6.5, 5)]]
# chosen metrics:  [[5.75, 6.75], [5.5, 6.5]]
# all candidates:  166 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  167 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(10.0, 4), (12.0, 5)]
# all candidates:  168 [[(10.0, 4), (12.0, 5)]]
# all cands right before mindst:  [[(10.0, 4), (12.0, 5)]]
# chosen metrics:  [[10.0, 12.0]]
# candidates after SC:  [(10.0, 4), (15.0, 5)]
# candidates after SC:  []
# all candidates:  169 [[(10.0, 4), (15.0, 5)]]
# all cands right before mindst:  [[(10.0, 4), (15.0, 5)]]
# chosen metrics:  [[10.0, 15.0]]
# candidates after SC:  [(11.0, 3), (13.0, 4)]
# candidates after SC:  [(11.0, 3), (13.0, 4)]
# all candidates:  170 [[(11.0, 3), (13.0, 4)], [(11.0, 3), (13.0, 4)]]
# all cands right before mindst:  [[(11.0, 3), (13.0, 4)], [(11.0, 3), (13.0, 4)]]
# chosen metrics:  [[11.0, 13.0], [11.0, 13.0]]
# candidates after SC:  [(11.3, 7)]
# candidates after SC:  []
# candidates after SC:  []
# all candidates:  171 [[(11.3, 7)]]
# all cands right before mindst:  [[(11.3, 7)]]
# chosen metrics:  [[11.3]]
# all candidates:  172 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  173 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(13.0, 3), (17.0, 4)]
# all candidates:  174 [[(13.0, 3), (17.0, 4)]]
# all cands right before mindst:  [[(13.0, 3), (17.0, 4)]]
# chosen metrics:  [[13.0, 17.0]]
# candidates after SC:  []
# candidates after SC:  [(8.5, 4), (9.5, 3)]
# candidates after SC:  []
# candidates after SC:  [(8.5, 4), (9.5, 3)]
# candidates after SC:  []
# candidates after SC:  [(8.0, 5), (9.0, 3)]
# all candidates:  175 [[(8.5, 4), (9.5, 3)], [(8.5, 4), (9.5, 3)], [(8.0, 5), (9.0, 3)]]
# all cands right before mindst:  [[(8.5, 4), (9.5, 3)], [(8.5, 4), (9.5, 3)], [(8.0, 5), (9.0, 3)]]
# chosen metrics:  [[8.5, 9.5], [8.5, 9.5], [8.0, 9.0]]
# candidates after SC:  []
# all candidates:  176 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(16.0, 3), (22.0, 4)]
# candidates after SC:  []
# all candidates:  177 [[(16.0, 3), (22.0, 4)]]
# all cands right before mindst:  [[(16.0, 3), (22.0, 4)]]
# chosen metrics:  [[16.0, 22.0]]
# candidates after SC:  [(11.0, 4), (14.0, 5)]
# candidates after SC:  []
# all candidates:  178 [[(11.0, 4), (14.0, 5)]]
# all cands right before mindst:  [[(11.0, 4), (14.0, 5)]]
# chosen metrics:  [[11.0, 14.0]]
# candidates after SC:  [(100.0, 13), (65.8, 11), (3.0, 13), (10.0, 4)]
# all candidates:  179 [[(100.0, 13), (65.8, 11), (3.0, 13), (10.0, 4)]]
# all cands right before mindst:  [[(100.0, 13), (65.8, 11), (3.0, 13), (10.0, 4)]]
# chosen metrics:  [[10.0]]
# candidates after SC:  [(7.0, 6), (8.0, 7)]
# candidates after SC:  []
# all candidates:  180 [[(7.0, 6), (8.0, 7)]]
# all cands right before mindst:  [[(7.0, 6), (8.0, 7)]]
# chosen metrics:  [[7.0, 8.0]]
# candidates after SC:  [(11.7, 3), (13.7, 4)]
# candidates after SC:  [(11.7, 4), (13.7, 5)]
# all candidates:  181 [[(11.7, 3), (13.7, 4)], [(11.7, 4), (13.7, 5)]]
# all cands right before mindst:  [[(11.7, 3), (13.7, 4)], [(11.7, 4), (13.7, 5)]]
# chosen metrics:  [[11.7, 13.7], [11.7, 13.7]]
# candidates after SC:  []
# candidates after SC:  [(10.0, 4), (12.0, 3)]
# candidates after SC:  []
# all candidates:  182 [[(10.0, 4), (12.0, 3)]]
# all cands right before mindst:  [[(10.0, 4), (12.0, 3)]]
# chosen metrics:  [[10.0, 12.0]]
# candidates after SC:  [(10.5, 4), (12.5, 5)]
# all candidates:  183 [[(10.5, 4), (12.5, 5)]]
# all cands right before mindst:  [[(10.5, 4), (12.5, 5)]]
# chosen metrics:  [[10.5, 12.5]]
# candidates after SC:  []
# candidates after SC:  [(3.5, 6), (22.0, 2), (26.0, 4)]
# all candidates:  184 [[(3.5, 6), (22.0, 2), (26.0, 4)]]
# all cands right before mindst:  [[(3.5, 6), (22.0, 2), (26.0, 4)]]
# chosen metrics:  [[22.0, 26.0]]
# all candidates:  185 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(7.1, 5), (8.1, 3)]
# all candidates:  186 [[(7.1, 5), (8.1, 3)]]
# all cands right before mindst:  [[(7.1, 5), (8.1, 3)]]
# chosen metrics:  [[7.1, 8.1]]
# candidates after SC:  [(39.0, 7), (10.5, 4)]
# all candidates:  187 [[(39.0, 7), (10.5, 4)]]
# all cands right before mindst:  [[(39.0, 7), (10.5, 4)]]
# chosen metrics:  [[10.5]]
# candidates after SC:  [(10.0, 4), (12.0, 3)]
# candidates after SC:  []
# all candidates:  188 [[(10.0, 4), (12.0, 3)]]
# all cands right before mindst:  [[(10.0, 4), (12.0, 3)]]
# chosen metrics:  [[10.0, 12.0]]
# candidates after SC:  []
# all candidates:  189 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(11.0, 5), (11.5, 4)]
# all candidates:  190 [[(11.0, 5), (11.5, 4)]]
# all cands right before mindst:  [[(11.0, 5), (11.5, 4)]]
# chosen metrics:  [[11.0, 11.5]]
# candidates after SC:  [(12.0, 4), (16.0, 5)]
# candidates after SC:  []
# all candidates:  191 [[(12.0, 4), (16.0, 5)]]
# all cands right before mindst:  [[(12.0, 4), (16.0, 5)]]
# chosen metrics:  [[12.0, 16.0]]
# candidates after SC:  []
# candidates after SC:  []
# candidates after SC:  []
# all candidates:  192 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(7.0, 4), (9.0, 5), (8.5, 7)]
# all candidates:  193 [[(7.0, 4), (9.0, 5), (8.5, 7)]]
# all cands right before mindst:  [[(7.0, 4), (9.0, 5), (8.5, 7)]]
# chosen metrics:  [[7.0, 9.0]]
# candidates after SC:  [(7.2, 4), (7.6, 5)]
# all candidates:  194 [[(7.2, 4), (7.6, 5)]]
# all cands right before mindst:  [[(7.2, 4), (7.6, 5)]]
# chosen metrics:  [[7.2, 7.6]]
# all candidates:  195 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  196 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  197 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(8.5, 3), (9.5, 4)]
# all candidates:  198 [[(8.5, 3), (9.5, 4)]]
# all cands right before mindst:  [[(8.5, 3), (9.5, 4)]]
# chosen metrics:  [[8.5, 9.5]]
# candidates after SC:  []
# candidates after SC:  [(7.5, 6), (8.5, 6), (8.0, 6)]
# all candidates:  199 [[(7.5, 6), (8.5, 6), (8.0, 6)]]
# all cands right before mindst:  [[(7.5, 6), (8.5, 6), (8.0, 6)]]
# chosen metrics:  [[7.5, 8.5, 8.0]]
# candidates after SC:  []
# all candidates:  200 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(8.0, 4), (10.0, 5)]
# all candidates:  201 [[(8.0, 4), (10.0, 5)]]
# all cands right before mindst:  [[(8.0, 4), (10.0, 5)]]
# chosen metrics:  [[8.0, 10.0]]
# candidates after SC:  [(10.5, 4), (13.5, 5)]
# all candidates:  202 [[(10.5, 4), (13.5, 5)]]
# all cands right before mindst:  [[(10.5, 4), (13.5, 5)]]
# chosen metrics:  [[10.5, 13.5]]
# candidates after SC:  [(9.5, 4), (11.5, 5)]
# all candidates:  203 [[(9.5, 4), (11.5, 5)]]
# all cands right before mindst:  [[(9.5, 4), (11.5, 5)]]
# chosen metrics:  [[9.5, 11.5]]
# all candidates:  204 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  205 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(8.0, 3), (9.0, 4)]
# all candidates:  206 [[(8.0, 3), (9.0, 4)]]
# all cands right before mindst:  [[(8.0, 3), (9.0, 4)]]
# chosen metrics:  [[8.0, 9.0]]
# candidates after SC:  []
# all candidates:  207 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(11.5, 4)]
# candidates after SC:  [(11.5, 3), (12.5, 6)]
# candidates after SC:  []
# all candidates:  208 [[(11.5, 4)], [(11.5, 3), (12.5, 6)]]
# all cands right before mindst:  [[(11.5, 4)], [(11.5, 3), (12.5, 6)]]
# chosen metrics:  [[11.5], [11.5]]
# all candidates:  209 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(7.0, 4), (9.0, 5), (12.0, 2), (14.0, 4)]
# all candidates:  210 [[(7.0, 4), (9.0, 5), (12.0, 2), (14.0, 4)]]
# all cands right before mindst:  [[(7.0, 4), (9.0, 5), (12.0, 2), (14.0, 4)]]
# chosen metrics:  [[7.0, 12.0, 14.0]]
# all candidates:  211 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(8.0, 4), (10.5, 5)]
# all candidates:  212 [[(8.0, 4), (10.5, 5)]]
# all cands right before mindst:  [[(8.0, 4), (10.5, 5)]]
# chosen metrics:  [[8.0, 10.5]]
# candidates after SC:  [(8.75, 4)]
# all candidates:  213 [[(8.75, 4)]]
# all cands right before mindst:  [[(8.75, 4)]]
# chosen metrics:  [[8.75]]
# candidates after SC:  [(8.5, 4), (10.5, 5)]
# all candidates:  214 [[(8.5, 4), (10.5, 5)]]
# all cands right before mindst:  [[(8.5, 4), (10.5, 5)]]
# chosen metrics:  [[8.5, 10.5]]
# candidates after SC:  [(15.5, 4), (17.5, 5)]
# candidates after SC:  []
# all candidates:  215 [[(15.5, 4), (17.5, 5)]]
# all cands right before mindst:  [[(15.5, 4), (17.5, 5)]]
# chosen metrics:  [[15.5, 17.5]]
# all candidates:  216 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  217 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  218 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  219 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  220 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(12.5, 4), (14.5, 5)]
# all candidates:  221 [[(12.5, 4), (14.5, 5)]]
# all cands right before mindst:  [[(12.5, 4), (14.5, 5)]]
# chosen metrics:  [[12.5, 14.5]]
# all candidates:  222 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  223 []
# empty allcadnidates in mindst
# chosen metrics:  []
# all candidates:  224 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(10.1, 4), (11.8, 5)]
# all candidates:  225 [[(10.1, 4), (11.8, 5)]]
# all cands right before mindst:  [[(10.1, 4), (11.8, 5)]]
# chosen metrics:  [[10.1, 11.8]]
# candidates after SC:  []
# all candidates:  226 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(7.5, 4), (10.0, 5)]
# all candidates:  227 [[(7.5, 4), (10.0, 5)]]
# all cands right before mindst:  [[(7.5, 4), (10.0, 5)]]
# chosen metrics:  [[7.5, 10.0]]
# candidates after SC:  [(9.75, 6), (11.0, 7)]
# all candidates:  228 [[(9.75, 6), (11.0, 7)]]
# all cands right before mindst:  [[(9.75, 6), (11.0, 7)]]
# chosen metrics:  [[9.75, 11.0]]
# candidates after SC:  []
# all candidates:  229 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(11.0, 4), (15.0, 5)]
# candidates after SC:  []
# all candidates:  230 [[(11.0, 4), (15.0, 5)]]
# all cands right before mindst:  [[(11.0, 4), (15.0, 5)]]
# chosen metrics:  [[11.0, 15.0]]
# candidates after SC:  [(13.0, 5)]
# candidates after SC:  [(10.5, 4), (13.0, 5)]
# all candidates:  231 [[(13.0, 5)], [(10.5, 4), (13.0, 5)]]
# all cands right before mindst:  [[(13.0, 5)], [(10.5, 4), (13.0, 5)]]
# chosen metrics:  [[13.0], [10.5, 13.0]]
# all candidates:  232 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(11.0, 4), (15.0, 5)]
# candidates after SC:  []
# all candidates:  233 [[(11.0, 4), (15.0, 5)]]
# all cands right before mindst:  [[(11.0, 4), (15.0, 5)]]
# chosen metrics:  [[11.0, 15.0]]
# candidates after SC:  [(7.0, 4), (11.0, 5)]
# candidates after SC:  [(7.0, 4), (11.0, 5)]
# candidates after SC:  [(7.0, 4), (3.5, 17)]
# all candidates:  234 [[(7.0, 4), (11.0, 5)], [(7.0, 4), (11.0, 5)], [(7.0, 4), (3.5, 17)]]
# all cands right before mindst:  [[(7.0, 4), (11.0, 5)], [(7.0, 4), (11.0, 5)], [(7.0, 4), (3.5, 17)]]
# chosen metrics:  [[7.0, 11.0], [7.0, 11.0], [7.0]]
# candidates after SC:  [(12.0, 5)]
# candidates after SC:  []
# all candidates:  235 [[(12.0, 5)]]
# all cands right before mindst:  [[(12.0, 5)]]
# chosen metrics:  [[12.0]]
# candidates after SC:  [(9.0, 4), (10.0, 5)]
# candidates after SC:  []
# all candidates:  236 [[(9.0, 4), (10.0, 5)]]
# all cands right before mindst:  [[(9.0, 4), (10.0, 5)]]
# chosen metrics:  [[9.0, 10.0]]
# candidates after SC:  [(13.0, 4), (17.0, 5)]
# all candidates:  237 [[(13.0, 4), (17.0, 5)]]
# all cands right before mindst:  [[(13.0, 4), (17.0, 5)]]
# chosen metrics:  [[13.0, 17.0]]
# all candidates:  238 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(10.0, 4), (12.0, 5)]
# candidates after SC:  [(4.4, 6), (7.8, 7)]
# all candidates:  239 [[(10.0, 4), (12.0, 5)], [(4.4, 6), (7.8, 7)]]
# all cands right before mindst:  [[(10.0, 4), (12.0, 5)], [(4.4, 6), (7.8, 7)]]
# chosen metrics:  [[10.0, 12.0], [4.4]]
# all candidates:  240 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(3.0, 12)]
# candidates after SC:  [(8.0, 6), (10.0, 4)]
# candidates after SC:  []
# candidates after SC:  [(8.0, 6), (10.0, 4)]
# candidates after SC:  []
# all candidates:  241 [[(3.0, 12)], [(8.0, 6), (10.0, 4)], [(8.0, 6), (10.0, 4)]]
# all cands right before mindst:  [[(3.0, 12)], [(8.0, 6), (10.0, 4)], [(8.0, 6), (10.0, 4)]]
# chosen metrics:  [[8.0, 10.0], [8.0, 10.0]]
# all candidates:  242 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  []
# candidates after SC:  [(11.5, 4), (12.5, 5)]
# all candidates:  243 [[(11.5, 4), (12.5, 5)]]
# all cands right before mindst:  [[(11.5, 4), (12.5, 5)]]
# chosen metrics:  [[11.5, 12.5]]
# candidates after SC:  [(14.0, 4), (16.0, 5)]
# candidates after SC:  []
# all candidates:  244 [[(14.0, 4), (16.0, 5)]]
# all cands right before mindst:  [[(14.0, 4), (16.0, 5)]]
# chosen metrics:  [[14.0, 16.0]]
# candidates after SC:  [(19.0, 4), (22.0, 5)]
# all candidates:  245 [[(19.0, 4), (22.0, 5)]]
# all cands right before mindst:  [[(19.0, 4), (22.0, 5)]]
# chosen metrics:  [[19.0, 22.0]]
# candidates after SC:  [(8.0, 4), (11.0, 5)]
# candidates after SC:  []
# all candidates:  246 [[(8.0, 4), (11.0, 5)]]
# all cands right before mindst:  [[(8.0, 4), (11.0, 5)]]
# chosen metrics:  [[8.0, 11.0]]
# candidates after SC:  [(11.0, 5), (13.0, 4)]
# all candidates:  247 [[(11.0, 5), (13.0, 4)]]
# all cands right before mindst:  [[(11.0, 5), (13.0, 4)]]
# chosen metrics:  [[11.0, 13.0]]
# all candidates:  248 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  [(11.0, 4), (12.0, 5)]
# all candidates:  249 [[(11.0, 4), (12.0, 5)]]
# all cands right before mindst:  [[(11.0, 4), (12.0, 5)]]
# chosen metrics:  [[11.0, 12.0]]
# all candidates:  250 []
# empty allcadnidates in mindst
# chosen metrics:  []
# candidates after SC:  []
# candidates after SC:  [(9.0, 3), (10.0, 3)]
# all candidates:  251 [[(9.0, 3), (10.0, 3)]]
# all cands right before mindst:  [[(9.0, 3), (10.0, 3)]]
# chosen metrics:  [[9.0, 10.0]]
# candidates after SC:  [(12.6, 4), (14.6, 5)]
# all candidates:  252 [[(12.6, 4), (14.6, 5)]]
# all cands right before mindst:  [[(12.6, 4), (14.6, 5)]]
# chosen metrics:  [[12.6, 14.6]]
# candidates after SC:  [(10.5, 3), (11.5, 4)]
# candidates after SC:  [(9.0, 3), (10.0, 4)]
# candidates after SC:  []
# candidates after SC:  []
# candidates after SC:  [(10.5, 6), (11.5, 7)]
# all candidates:  253 [[(10.5, 3), (11.5, 4)], [(9.0, 3), (10.0, 4)], [(10.5, 6), (11.5, 7)]]
# all cands right before mindst:  [[(10.5, 3), (11.5, 4)], [(9.0, 3), (10.0, 4)], [(10.5, 6), (11.5, 7)]]
# chosen metrics:  [[10.5, 11.5], [9.0, 10.0]]
# candidates after SC:  [(10.5, 4), (11.0, 5)]
# candidates after SC:  []
# all candidates:  254 [[(10.5, 4), (11.0, 5)]]
# all cands right before mindst:  [[(10.5, 4), (11.0, 5)]]
# chosen metrics:  [[10.5, 11.0]]
# candidates after SC:  [(6.0, 4), (7.0, 5)]
# all candidates:  255 [[(6.0, 4), (7.0, 5)]]
# all cands right before mindst:  [[(6.0, 4), (7.0, 5)]]
# chosen metrics:  [[6.0, 7.0]]
# candidates after SC:  [(5.0, 4), (17.0, 3), (19.0, 4), (15.0, 2), (17.0, 3)]
# candidates after SC:  []
# all candidates:  256 [[(5.0, 4), (17.0, 3), (19.0, 4), (15.0, 2), (17.0, 3)]]
# all cands right before mindst:  [[(5.0, 4), (17.0, 3), (19.0, 4), (15.0, 2), (17.0, 3)]]
# chosen metrics:  [[5.0, 17.0, 19.0, 15.0, 17.0]]

# %%
predicted_metrics
# Out:
# [[[12.0, 16.0]],
#  [],
#  [],
#  [],
#  [[23.4]],
#  [[11.0, 13.0]],
#  [[9.0, 11.0]],
#  [],
#  [[16.0, 17.0]],
#  [[9.0, 12.0]],
#  [[5.2, 6.1]],
#  [],
#  [],
#  [[9.25, 10.25], [9.75, 10.75], [9.25, 10.25]],
#  [[9.5, 11.5]],
#  [[9.0, 11.0]],
#  [],
#  [[9.5, 11.5]],
#  [[10.5, 12.5, 1.0, 2.0]],
#  [[10.8, 12.8], [9.1, 11.1]],
#  [],
#  [[8.0, 10.0], [9.0, 11.0]],
#  [[12.75, 13.75], [10.0, 11.0]],
#  [[9.5]],
#  [[9.0, 11.0]],
#  [[10.0, 12.0]],
#  [[17.8, 20.8]],
#  [[18.3, 20.3, 2.0, 4.0]],
#  [[25.0, 23.3], [25.0, 23.7]],
#  [],
#  [[10.0, 12.0]],
#  [],
#  [],
#  [[19.0, 21.0]],
#  [[7.0, 8.0]],
#  [[7.3, 9.3], [7.7]],
#  [[10.2], [16.8]],
#  [[13.5]],
#  [[12.0, 14.0]],
#  [[5.0]],
#  [[8.5, 10.5]],
#  [[8.0, 7.0]],
#  [],
#  [[7.0, 8.0]],
#  [[10.5, 11.5], [11.0, 12.0]],
#  [[7.0]],
#  [[8.5, 10.0]],
#  [[10.0]],
#  [[9.5, 11.5], [9.5, 11.5], [9.5, 11.5], [9.5, 11.5]],
#  [[9.5, 10.5]],
#  [[11.5, 12.5]],
#  [[12.0, 16.0]],
#  [],
#  [[10.75, 11.75], [10.75, 11.75]],
#  [],
#  [],
#  [],
#  [[11.95, 19.0, 25.0]],
#  [[8.5, 10.5], [8.5, 10.5]],
#  [[9.0, 11.0], [8.0, 10.0, 1.0], [8.0, 10.0]],
#  [[15.0, 20.0]],
#  [[13.8]],
#  [],
#  [],
#  [],
#  [[11.0], [11.0, 13.0], [11.0, 13.0]],
#  [[8.5, 9.0], [8.5, 9.0]],
#  [[16.0]],
#  [[12.25, 14.25]],
#  [],
#  [],
#  [[9.5]],
#  [[9.0, 10.0]],
#  [[10.0, 8.0, 1.286]],
#  [],
#  [[10.0, 15.5]],
#  [],
#  [[13.0, 15.0], [13.0, 15.0]],
#  [],
#  [[3.0, 12.0, 16.0]],
#  [[1.0], [13.0, 17.0]],
#  [[17.5, 17.4, 1.0, 15.0, 23.0], [15.0, 23.0]],
#  [[12.0]],
#  [[16.0]],
#  [[9.5, 13.5]],
#  [],
#  [[9.0]],
#  [[7.5, 9.0], [7.5, 9.0]],
#  [],
#  [[9.5, 11.5]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[18.0, 24.0]],
#  [[32.0, 24.0, 29.0]],
#  [[12.0, 15.0], [10.0, 13.0]],
#  [],
#  [[10.0, 12.5, 15.0]],
#  [[6.2]],
#  [[23.0], [20.0, 23.0]],
#  [[8.0, 9.0], [8.5, 9.5]],
#  [[15.0, 20.0]],
#  [[21.0]],
#  [[10.4, 14.4]],
#  [[11.5, 13.5]],
#  [[8.6, 10.0], [8.0, 9.4]],
#  [],
#  [[7.5, 9.5]],
#  [[10.5]],
#  [[11.0, 13.0]],
#  [[9.0, 12.0]],
#  [[18.0, 22.0]],
#  [[7.9, 8.9], [7.0, 8.0]],
#  [[7.5, 8.5]],
#  [[7.0, 9.0], [7.0, 9.0]],
#  [],
#  [],
#  [[7.25, 7.75], [7.25, 7.75]],
#  [],
#  [[8.5, 10.5], [8.5], [6.4, 8.4], [6.4, 8.4], [7.5]],
#  [[9.0, 13.0], [9.0, 13.0]],
#  [[7.5, 8.5]],
#  [],
#  [[11.0, 15.0]],
#  [],
#  [],
#  [[11.5]],
#  [[14.4, 16.4]],
#  [[18.0]],
#  [[10.3, 12.3]],
#  [],
#  [[9.0], [9.0, 14.0]],
#  [[10.0, 12.3]],
#  [],
#  [[10.0, 11.0], [8.0, 9.0]],
#  [],
#  [],
#  [[9.0, 10.1]],
#  [[8.5, 9.5]],
#  [],
#  [[8.0, 10.0], [8.0, 10.0]],
#  [[7.9, 8.9], [7.0, 8.0]],
#  [[8.75]],
#  [],
#  [],
#  [],
#  [[7.0, 8.0]],
#  [[8.9, 10.9]],
#  [],
#  [[11.8, 13.8]],
#  [],
#  [],
#  [],
#  [[11.0, 15.0]],
#  [],
#  [[8.0, 10.0]],
#  [],
#  [[5.75, 6.75], [5.5, 6.5]],
#  [],
#  [],
#  [[10.0, 12.0]],
#  [[10.0, 15.0]],
#  [[11.0, 13.0], [11.0, 13.0]],
#  [[11.3]],
#  [],
#  [],
#  [[13.0, 17.0]],
#  [[8.5, 9.5], [8.5, 9.5], [8.0, 9.0]],
#  [],
#  [[16.0, 22.0]],
#  [[11.0, 14.0]],
#  [[10.0]],
#  [[7.0, 8.0]],
#  [[11.7, 13.7], [11.7, 13.7]],
#  [[10.0, 12.0]],
#  [[10.5, 12.5]],
#  [[22.0, 26.0]],
#  [],
#  [[7.1, 8.1]],
#  [[10.5]],
#  [[10.0, 12.0]],
#  [],
#  [[11.0, 11.5]],
#  [[12.0, 16.0]],
#  [],
#  [[7.0, 9.0]],
#  [[7.2, 7.6]],
#  [],
#  [],
#  [],
#  [[8.5, 9.5]],
#  [[7.5, 8.5, 8.0]],
#  [],
#  [[8.0, 10.0]],
#  [[10.5, 13.5]],
#  [[9.5, 11.5]],
#  [],
#  [],
#  [[8.0, 9.0]],
#  [],
#  [[11.5], [11.5]],
#  [],
#  [[7.0, 12.0, 14.0]],
#  [],
#  [[8.0, 10.5]],
#  [[8.75]],
#  [[8.5, 10.5]],
#  [[15.5, 17.5]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[12.5, 14.5]],
#  [],
#  [],
#  [],
#  [[10.1, 11.8]],
#  [],
#  [[7.5, 10.0]],
#  [[9.75, 11.0]],
#  [],
#  [[11.0, 15.0]],
#  [[13.0], [10.5, 13.0]],
#  [],
#  [[11.0, 15.0]],
#  [[7.0, 11.0], [7.0, 11.0], [7.0]],
#  [[12.0]],
#  [[9.0, 10.0]],
#  [[13.0, 17.0]],
#  [],
#  [[10.0, 12.0], [4.4]],
#  [],
#  [[8.0, 10.0], [8.0, 10.0]],
#  [],
#  [[11.5, 12.5]],
#  [[14.0, 16.0]],
#  [[19.0, 22.0]],
#  [[8.0, 11.0]],
#  [[11.0, 13.0]],
#  [],
#  [[11.0, 12.0]],
#  [],
#  [[9.0, 10.0]],
#  [[12.6, 14.6]],
#  [[10.5, 11.5], [9.0, 10.0]],
#  [[10.5, 11.0]],
#  [[6.0, 7.0]],
#  [[5.0, 17.0, 19.0, 15.0, 17.0]]]

# %%
spacy.displacy.serve(sentence, style='dep')
# Out:
# /Users/danielhuang/anaconda3/envs/nlu/lib/python3.7/runpy.py:193: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   "__main__", mod_spec)
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e2549220bd454fd8ab23677db3cfc4b2-0" class="displacy" width="4950" height="749.5" direction="ltr" style="max-width: none; height: 749.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">performing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">analysis,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">kbw</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">used</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">earnings</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">asset</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">growth</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">estimates</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">cadence</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">2010</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">through</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">2015</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">company</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">management</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">assumed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">discountrates</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">ranging</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">12.0%</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">16.0%.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e2549220bd454fd8ab23677db3cfc4b2-0-0" stroke-width="2px" d="M70,614.5 C70,177.0 915.0,177.0 915.0,614.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e2549220bd454fd8ab23677db3cfc4b2-0-0" class="displacy-label" st
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.
